# %% [markdown]
# ## Is a number prime?
#
# This notebook will attempt to answer the afore mentioned question with a simple algorithm that takes tries to see if the candidate numebr has any divisors

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from scipy import stats
# %matplotlib notebook
import timeit

# %% [markdown]
# First we're going to define the potential divisors of a test number

# %%
start = timeit.default_timer()

test_number=2000
potential_divisors=np.arange(2,test_number-1)
# print(potential_divisors)

# %% [markdown]
# Now we're going to loop over all ther possible divisors and see if they are or aren't a divisor

# %%
is_number_prime=False

for divisor in potential_divisors:
    print("Currently testing potential divisor: "+str(divisor))
    remainder=test_number%divisor
    
    #if remainder is zero the the number is a divisor so make the is_number_prime be true
    if remainder == 0:
        print('Aha! Found a divisor '+str(test_number)+' is divisble by '+str(divisor))
        is_number_prime=True
# Out:
# Currently testing potential divisor: 2
# Aha! Found a divisor 2000 is divisble by 2
# Currently testing potential divisor: 3
# Currently testing potential divisor: 4
# Aha! Found a divisor 2000 is divisble by 4
# Currently testing potential divisor: 5
# Aha! Found a divisor 2000 is divisble by 5
# Currently testing potential divisor: 6
# Currently testing potential divisor: 7
# Currently testing potential divisor: 8
# Aha! Found a divisor 2000 is divisble by 8
# Currently testing potential divisor: 9
# Currently testing potential divisor: 10
# Aha! Found a divisor 2000 is divisble by 10
# Currently testing potential divisor: 11
# Currently testing potential divisor: 12
# Currently testing potential divisor: 13
# Currently testing potential divisor: 14
# Currently testing potential divisor: 15
# Currently testing potential divisor: 16
# Aha! Found a divisor 2000 is divisble by 16
# Currently testing potential divisor: 17
# Currently testing potential divisor: 18
# Currently testing potential divisor: 19
# Currently testing potential divisor: 20
# Aha! Found a divisor 2000 is divisble by 20
# Currently testing potential divisor: 21
# Currently testing potential divisor: 22
# Currently testing potential divisor: 23
# Currently testing potential divisor: 24
# Currently testing potential divisor: 25
# Aha! Found a divisor 2000 is divisble by 25
# Currently testing potential divisor: 26
# Currently testing potential divisor: 27
# Currently testing potential divisor: 28
# Currently testing potential divisor: 29
# Currently testing potential divisor: 30
# Currently testing potential divisor: 31
# Currently testing potential divisor: 32
# Currently testing potential divisor: 33
# Currently testing potential divisor: 34
# Currently testing potential divisor: 35
# Currently testing potential divisor: 36
# Currently testing potential divisor: 37
# Currently testing potential divisor: 38
# Currently testing potential divisor: 39
# Currently testing potential divisor: 40
# Aha! Found a divisor 2000 is divisble by 40
# Currently testing potential divisor: 41
# Currently testing potential divisor: 42
# Currently testing potential divisor: 43
# Currently testing potential divisor: 44
# Currently testing potential divisor: 45
# Currently testing potential divisor: 46
# Currently testing potential divisor: 47
# Currently testing potential divisor: 48
# Currently testing potential divisor: 49
# Currently testing potential divisor: 50
# Aha! Found a divisor 2000 is divisble by 50
# Currently testing potential divisor: 51
# Currently testing potential divisor: 52
# Currently testing potential divisor: 53
# Currently testing potential divisor: 54
# Currently testing potential divisor: 55
# Currently testing potential divisor: 56
# Currently testing potential divisor: 57
# Currently testing potential divisor: 58
# Currently testing potential divisor: 59
# Currently testing potential divisor: 60
# Currently testing potential divisor: 61
# Currently testing potential divisor: 62
# Currently testing potential divisor: 63
# Currently testing potential divisor: 64
# Currently testing potential divisor: 65
# Currently testing potential divisor: 66
# Currently testing potential divisor: 67
# Currently testing potential divisor: 68
# Currently testing potential divisor: 69
# Currently testing potential divisor: 70
# Currently testing potential divisor: 71
# Currently testing potential divisor: 72
# Currently testing potential divisor: 73
# Currently testing potential divisor: 74
# Currently testing potential divisor: 75
# Currently testing potential divisor: 76
# Currently testing potential divisor: 77
# Currently testing potential divisor: 78
# Currently testing potential divisor: 79
# Currently testing potential divisor: 80
# Aha! Found a divisor 2000 is divisble by 80
# Currently testing potential divisor: 81
# Currently testing potential divisor: 82
# Currently testing potential divisor: 83
# Currently testing potential divisor: 84
# Currently testing potential divisor: 85
# Currently testing potential divisor: 86
# Currently testing potential divisor: 87
# Currently testing potential divisor: 88
# Currently testing potential divisor: 89
# Currently testing potential divisor: 90
# Currently testing potential divisor: 91
# Currently testing potential divisor: 92
# Currently testing potential divisor: 93
# Currently testing potential divisor: 94
# Currently testing potential divisor: 95
# Currently testing potential divisor: 96
# Currently testing potential divisor: 97
# Currently testing potential divisor: 98
# Currently testing potential divisor: 99
# Currently testing potential divisor: 100
# Aha! Found a divisor 2000 is divisble by 100
# Currently testing potential divisor: 101
# Currently testing potential divisor: 102
# Currently testing potential divisor: 103
# Currently testing potential divisor: 104
# Currently testing potential divisor: 105
# Currently testing potential divisor: 106
# Currently testing potential divisor: 107
# Currently testing potential divisor: 108
# Currently testing potential divisor: 109
# Currently testing potential divisor: 110
# Currently testing potential divisor: 111
# Currently testing potential divisor: 112
# Currently testing potential divisor: 113
# Currently testing potential divisor: 114
# Currently testing potential divisor: 115
# Currently testing potential divisor: 116
# Currently testing potential divisor: 117
# Currently testing potential divisor: 118
# Currently testing potential divisor: 119
# Currently testing potential divisor: 120
# Currently testing potential divisor: 121
# Currently testing potential divisor: 122
# Currently testing potential divisor: 123
# Currently testing potential divisor: 124
# Currently testing potential divisor: 125
# Aha! Found a divisor 2000 is divisble by 125
# Currently testing potential divisor: 126
# Currently testing potential divisor: 127
# Currently testing potential divisor: 128
# Currently testing potential divisor: 129
# Currently testing potential divisor: 130
# Currently testing potential divisor: 131
# Currently testing potential divisor: 132
# Currently testing potential divisor: 133
# Currently testing potential divisor: 134
# Currently testing potential divisor: 135
# Currently testing potential divisor: 136
# Currently testing potential divisor: 137
# Currently testing potential divisor: 138
# Currently testing potential divisor: 139
# Currently testing potential divisor: 140
# Currently testing potential divisor: 141
# Currently testing potential divisor: 142
# Currently testing potential divisor: 143
# Currently testing potential divisor: 144
# Currently testing potential divisor: 145
# Currently testing potential divisor: 146
# Currently testing potential divisor: 147
# Currently testing potential divisor: 148
# Currently testing potential divisor: 149
# Currently testing potential divisor: 150
# Currently testing potential divisor: 151
# Currently testing potential divisor: 152
# Currently testing potential divisor: 153
# Currently testing potential divisor: 154
# Currently testing potential divisor: 155
# Currently testing potential divisor: 156
# Currently testing potential divisor: 157
# Currently testing potential divisor: 158
# Currently testing potential divisor: 159
# Currently testing potential divisor: 160
# Currently testing potential divisor: 161
# Currently testing potential divisor: 162
# Currently testing potential divisor: 163
# Currently testing potential divisor: 164
# Currently testing potential divisor: 165
# Currently testing potential divisor: 166
# Currently testing potential divisor: 167
# Currently testing potential divisor: 168
# Currently testing potential divisor: 169
# Currently testing potential divisor: 170
# Currently testing potential divisor: 171
# Currently testing potential divisor: 172
# Currently testing potential divisor: 173
# Currently testing potential divisor: 174
# Currently testing potential divisor: 175
# Currently testing potential divisor: 176
# Currently testing potential divisor: 177
# Currently testing potential divisor: 178
# Currently testing potential divisor: 179
# Currently testing potential divisor: 180
# Currently testing potential divisor: 181
# Currently testing potential divisor: 182
# Currently testing potential divisor: 183
# Currently testing potential divisor: 184
# Currently testing potential divisor: 185
# Currently testing potential divisor: 186
# Currently testing potential divisor: 187
# Currently testing potential divisor: 188
# Currently testing potential divisor: 189
# Currently testing potential divisor: 190
# Currently testing potential divisor: 191
# Currently testing potential divisor: 192
# Currently testing potential divisor: 193
# Currently testing potential divisor: 194
# Currently testing potential divisor: 195
# Currently testing potential divisor: 196
# Currently testing potential divisor: 197
# Currently testing potential divisor: 198
# Currently testing potential divisor: 199
# Currently testing potential divisor: 200
# Aha! Found a divisor 2000 is divisble by 200
# Currently testing potential divisor: 201
# Currently testing potential divisor: 202
# Currently testing potential divisor: 203
# Currently testing potential divisor: 204
# Currently testing potential divisor: 205
# Currently testing potential divisor: 206
# Currently testing potential divisor: 207
# Currently testing potential divisor: 208
# Currently testing potential divisor: 209
# Currently testing potential divisor: 210
# Currently testing potential divisor: 211
# Currently testing potential divisor: 212
# Currently testing potential divisor: 213
# Currently testing potential divisor: 214
# Currently testing potential divisor: 215
# Currently testing potential divisor: 216
# Currently testing potential divisor: 217
# Currently testing potential divisor: 218
# Currently testing potential divisor: 219
# Currently testing potential divisor: 220
# Currently testing potential divisor: 221
# Currently testing potential divisor: 222
# Currently testing potential divisor: 223
# Currently testing potential divisor: 224
# Currently testing potential divisor: 225
# Currently testing potential divisor: 226
# Currently testing potential divisor: 227
# Currently testing potential divisor: 228
# Currently testing potential divisor: 229
# Currently testing potential divisor: 230
# Currently testing potential divisor: 231
# Currently testing potential divisor: 232
# Currently testing potential divisor: 233
# Currently testing potential divisor: 234
# Currently testing potential divisor: 235
# Currently testing potential divisor: 236
# Currently testing potential divisor: 237
# Currently testing potential divisor: 238
# Currently testing potential divisor: 239
# Currently testing potential divisor: 240
# Currently testing potential divisor: 241
# Currently testing potential divisor: 242
# Currently testing potential divisor: 243
# Currently testing potential divisor: 244
# Currently testing potential divisor: 245
# Currently testing potential divisor: 246
# Currently testing potential divisor: 247
# Currently testing potential divisor: 248
# Currently testing potential divisor: 249
# Currently testing potential divisor: 250
# Aha! Found a divisor 2000 is divisble by 250
# Currently testing potential divisor: 251
# Currently testing potential divisor: 252
# Currently testing potential divisor: 253
# Currently testing potential divisor: 254
# Currently testing potential divisor: 255
# Currently testing potential divisor: 256
# Currently testing potential divisor: 257
# Currently testing potential divisor: 258
# Currently testing potential divisor: 259
# Currently testing potential divisor: 260
# Currently testing potential divisor: 261
# Currently testing potential divisor: 262
# Currently testing potential divisor: 263
# Currently testing potential divisor: 264
# Currently testing potential divisor: 265
# Currently testing potential divisor: 266
# Currently testing potential divisor: 267
# Currently testing potential divisor: 268
# Currently testing potential divisor: 269
# Currently testing potential divisor: 270
# Currently testing potential divisor: 271
# Currently testing potential divisor: 272
# Currently testing potential divisor: 273
# Currently testing potential divisor: 274
# Currently testing potential divisor: 275
# Currently testing potential divisor: 276
# Currently testing potential divisor: 277
# Currently testing potential divisor: 278
# Currently testing potential divisor: 279
# Currently testing potential divisor: 280
# Currently testing potential divisor: 281
# Currently testing potential divisor: 282
# Currently testing potential divisor: 283
# Currently testing potential divisor: 284
# Currently testing potential divisor: 285
# Currently testing potential divisor: 286
# Currently testing potential divisor: 287
# Currently testing potential divisor: 288
# Currently testing potential divisor: 289
# Currently testing potential divisor: 290
# Currently testing potential divisor: 291
# Currently testing potential divisor: 292
# Currently testing potential divisor: 293
# Currently testing potential divisor: 294
# Currently testing potential divisor: 295
# Currently testing potential divisor: 296
# Currently testing potential divisor: 297
# Currently testing potential divisor: 298
# Currently testing potential divisor: 299
# Currently testing potential divisor: 300
# Currently testing potential divisor: 301
# Currently testing potential divisor: 302
# Currently testing potential divisor: 303
# Currently testing potential divisor: 304
# Currently testing potential divisor: 305
# Currently testing potential divisor: 306
# Currently testing potential divisor: 307
# Currently testing potential divisor: 308
# Currently testing potential divisor: 309
# Currently testing potential divisor: 310
# Currently testing potential divisor: 311
# Currently testing potential divisor: 312
# Currently testing potential divisor: 313
# Currently testing potential divisor: 314
# Currently testing potential divisor: 315
# Currently testing potential divisor: 316
# Currently testing potential divisor: 317
# Currently testing potential divisor: 318
# Currently testing potential divisor: 319
# Currently testing potential divisor: 320
# Currently testing potential divisor: 321
# Currently testing potential divisor: 322
# Currently testing potential divisor: 323
# Currently testing potential divisor: 324
# Currently testing potential divisor: 325
# Currently testing potential divisor: 326
# Currently testing potential divisor: 327
# Currently testing potential divisor: 328
# Currently testing potential divisor: 329
# Currently testing potential divisor: 330
# Currently testing potential divisor: 331
# Currently testing potential divisor: 332
# Currently testing potential divisor: 333
# Currently testing potential divisor: 334
# Currently testing potential divisor: 335
# Currently testing potential divisor: 336
# Currently testing potential divisor: 337
# Currently testing potential divisor: 338
# Currently testing potential divisor: 339
# Currently testing potential divisor: 340
# Currently testing potential divisor: 341
# Currently testing potential divisor: 342
# Currently testing potential divisor: 343
# Currently testing potential divisor: 344
# Currently testing potential divisor: 345
# Currently testing potential divisor: 346
# Currently testing potential divisor: 347
# Currently testing potential divisor: 348
# Currently testing potential divisor: 349
# Currently testing potential divisor: 350
# Currently testing potential divisor: 351
# Currently testing potential divisor: 352
# Currently testing potential divisor: 353
# Currently testing potential divisor: 354
# Currently testing potential divisor: 355
# Currently testing potential divisor: 356
# Currently testing potential divisor: 357
# Currently testing potential divisor: 358
# Currently testing potential divisor: 359
# Currently testing potential divisor: 360
# Currently testing potential divisor: 361
# Currently testing potential divisor: 362
# Currently testing potential divisor: 363
# Currently testing potential divisor: 364
# Currently testing potential divisor: 365
# Currently testing potential divisor: 366
# Currently testing potential divisor: 367
# Currently testing potential divisor: 368
# Currently testing potential divisor: 369
# Currently testing potential divisor: 370
# Currently testing potential divisor: 371
# Currently testing potential divisor: 372
# Currently testing potential divisor: 373
# Currently testing potential divisor: 374
# Currently testing potential divisor: 375
# Currently testing potential divisor: 376
# Currently testing potential divisor: 377
# Currently testing potential divisor: 378
# Currently testing potential divisor: 379
# Currently testing potential divisor: 380
# Currently testing potential divisor: 381
# Currently testing potential divisor: 382
# Currently testing potential divisor: 383
# Currently testing potential divisor: 384
# Currently testing potential divisor: 385
# Currently testing potential divisor: 386
# Currently testing potential divisor: 387
# Currently testing potential divisor: 388
# Currently testing potential divisor: 389
# Currently testing potential divisor: 390
# Currently testing potential divisor: 391
# Currently testing potential divisor: 392
# Currently testing potential divisor: 393
# Currently testing potential divisor: 394
# Currently testing potential divisor: 395
# Currently testing potential divisor: 396
# Currently testing potential divisor: 397
# Currently testing potential divisor: 398
# Currently testing potential divisor: 399
# Currently testing potential divisor: 400
# Aha! Found a divisor 2000 is divisble by 400
# Currently testing potential divisor: 401
# Currently testing potential divisor: 402
# Currently testing potential divisor: 403
# Currently testing potential divisor: 404
# Currently testing potential divisor: 405
# Currently testing potential divisor: 406
# Currently testing potential divisor: 407
# Currently testing potential divisor: 408
# Currently testing potential divisor: 409
# Currently testing potential divisor: 410
# Currently testing potential divisor: 411
# Currently testing potential divisor: 412
# Currently testing potential divisor: 413
# Currently testing potential divisor: 414
# Currently testing potential divisor: 415
# Currently testing potential divisor: 416
# Currently testing potential divisor: 417
# Currently testing potential divisor: 418
# Currently testing potential divisor: 419
# Currently testing potential divisor: 420
# Currently testing potential divisor: 421
# Currently testing potential divisor: 422
# Currently testing potential divisor: 423
# Currently testing potential divisor: 424
# Currently testing potential divisor: 425
# Currently testing potential divisor: 426
# Currently testing potential divisor: 427
# Currently testing potential divisor: 428
# Currently testing potential divisor: 429
# Currently testing potential divisor: 430
# Currently testing potential divisor: 431
# Currently testing potential divisor: 432
# Currently testing potential divisor: 433
# Currently testing potential divisor: 434
# Currently testing potential divisor: 435
# Currently testing potential divisor: 436
# Currently testing potential divisor: 437
# Currently testing potential divisor: 438
# Currently testing potential divisor: 439
# Currently testing potential divisor: 440
# Currently testing potential divisor: 441
# Currently testing potential divisor: 442
# Currently testing potential divisor: 443
# Currently testing potential divisor: 444
# Currently testing potential divisor: 445
# Currently testing potential divisor: 446
# Currently testing potential divisor: 447
# Currently testing potential divisor: 448
# Currently testing potential divisor: 449
# Currently testing potential divisor: 450
# Currently testing potential divisor: 451
# Currently testing potential divisor: 452
# Currently testing potential divisor: 453
# Currently testing potential divisor: 454
# Currently testing potential divisor: 455
# Currently testing potential divisor: 456
# Currently testing potential divisor: 457
# Currently testing potential divisor: 458
# Currently testing potential divisor: 459
# Currently testing potential divisor: 460
# Currently testing potential divisor: 461
# Currently testing potential divisor: 462
# Currently testing potential divisor: 463
# Currently testing potential divisor: 464
# Currently testing potential divisor: 465
# Currently testing potential divisor: 466
# Currently testing potential divisor: 467
# Currently testing potential divisor: 468
# Currently testing potential divisor: 469
# Currently testing potential divisor: 470
# Currently testing potential divisor: 471
# Currently testing potential divisor: 472
# Currently testing potential divisor: 473
# Currently testing potential divisor: 474
# Currently testing potential divisor: 475
# Currently testing potential divisor: 476
# Currently testing potential divisor: 477
# Currently testing potential divisor: 478
# Currently testing potential divisor: 479
# Currently testing potential divisor: 480
# Currently testing potential divisor: 481
# Currently testing potential divisor: 482
# Currently testing potential divisor: 483
# Currently testing potential divisor: 484
# Currently testing potential divisor: 485
# Currently testing potential divisor: 486
# Currently testing potential divisor: 487
# Currently testing potential divisor: 488
# Currently testing potential divisor: 489
# Currently testing potential divisor: 490
# Currently testing potential divisor: 491
# Currently testing potential divisor: 492
# Currently testing potential divisor: 493
# Currently testing potential divisor: 494
# Currently testing potential divisor: 495
# Currently testing potential divisor: 496
# Currently testing potential divisor: 497
# Currently testing potential divisor: 498
# Currently testing potential divisor: 499
# Currently testing potential divisor: 500
# Aha! Found a divisor 2000 is divisble by 500
# Currently testing potential divisor: 501
# Currently testing potential divisor: 502
# Currently testing potential divisor: 503
# Currently testing potential divisor: 504
# Currently testing potential divisor: 505
# Currently testing potential divisor: 506
# Currently testing potential divisor: 507
# Currently testing potential divisor: 508
# Currently testing potential divisor: 509
# Currently testing potential divisor: 510
# Currently testing potential divisor: 511
# Currently testing potential divisor: 512
# Currently testing potential divisor: 513
# Currently testing potential divisor: 514
# Currently testing potential divisor: 515
# Currently testing potential divisor: 516
# Currently testing potential divisor: 517
# Currently testing potential divisor: 518
# Currently testing potential divisor: 519
# Currently testing potential divisor: 520
# Currently testing potential divisor: 521
# Currently testing potential divisor: 522
# Currently testing potential divisor: 523
# Currently testing potential divisor: 524
# Currently testing potential divisor: 525
# Currently testing potential divisor: 526
# Currently testing potential divisor: 527
# Currently testing potential divisor: 528
# Currently testing potential divisor: 529
# Currently testing potential divisor: 530
# Currently testing potential divisor: 531
# Currently testing potential divisor: 532
# Currently testing potential divisor: 533
# Currently testing potential divisor: 534
# Currently testing potential divisor: 535
# Currently testing potential divisor: 536
# Currently testing potential divisor: 537
# Currently testing potential divisor: 538
# Currently testing potential divisor: 539
# Currently testing potential divisor: 540
# Currently testing potential divisor: 541
# Currently testing potential divisor: 542
# Currently testing potential divisor: 543
# Currently testing potential divisor: 544
# Currently testing potential divisor: 545
# Currently testing potential divisor: 546
# Currently testing potential divisor: 547
# Currently testing potential divisor: 548
# Currently testing potential divisor: 549
# Currently testing potential divisor: 550
# Currently testing potential divisor: 551
# Currently testing potential divisor: 552
# Currently testing potential divisor: 553
# Currently testing potential divisor: 554
# Currently testing potential divisor: 555
# Currently testing potential divisor: 556
# Currently testing potential divisor: 557
# Currently testing potential divisor: 558
# Currently testing potential divisor: 559
# Currently testing potential divisor: 560
# Currently testing potential divisor: 561
# Currently testing potential divisor: 562
# Currently testing potential divisor: 563
# Currently testing potential divisor: 564
# Currently testing potential divisor: 565
# Currently testing potential divisor: 566
# Currently testing potential divisor: 567
# Currently testing potential divisor: 568
# Currently testing potential divisor: 569
# Currently testing potential divisor: 570
# Currently testing potential divisor: 571
# Currently testing potential divisor: 572
# Currently testing potential divisor: 573
# Currently testing potential divisor: 574
# Currently testing potential divisor: 575
# Currently testing potential divisor: 576
# Currently testing potential divisor: 577
# Currently testing potential divisor: 578
# Currently testing potential divisor: 579
# Currently testing potential divisor: 580
# Currently testing potential divisor: 581
# Currently testing potential divisor: 582
# Currently testing potential divisor: 583
# Currently testing potential divisor: 584
# Currently testing potential divisor: 585
# Currently testing potential divisor: 586
# Currently testing potential divisor: 587
# Currently testing potential divisor: 588
# Currently testing potential divisor: 589
# Currently testing potential divisor: 590
# Currently testing potential divisor: 591
# Currently testing potential divisor: 592
# Currently testing potential divisor: 593
# Currently testing potential divisor: 594
# Currently testing potential divisor: 595
# Currently testing potential divisor: 596
# Currently testing potential divisor: 597
# Currently testing potential divisor: 598
# Currently testing potential divisor: 599
# Currently testing potential divisor: 600
# Currently testing potential divisor: 601
# Currently testing potential divisor: 602
# Currently testing potential divisor: 603
# Currently testing potential divisor: 604
# Currently testing potential divisor: 605
# Currently testing potential divisor: 606
# Currently testing potential divisor: 607
# Currently testing potential divisor: 608
# Currently testing potential divisor: 609
# Currently testing potential divisor: 610
# Currently testing potential divisor: 611
# Currently testing potential divisor: 612
# Currently testing potential divisor: 613
# Currently testing potential divisor: 614
# Currently testing potential divisor: 615
# Currently testing potential divisor: 616
# Currently testing potential divisor: 617
# Currently testing potential divisor: 618
# Currently testing potential divisor: 619
# Currently testing potential divisor: 620
# Currently testing potential divisor: 621
# Currently testing potential divisor: 622
# Currently testing potential divisor: 623
# Currently testing potential divisor: 624
# Currently testing potential divisor: 625
# Currently testing potential divisor: 626
# Currently testing potential divisor: 627
# Currently testing potential divisor: 628
# Currently testing potential divisor: 629
# Currently testing potential divisor: 630
# Currently testing potential divisor: 631
# Currently testing potential divisor: 632
# Currently testing potential divisor: 633
# Currently testing potential divisor: 634
# Currently testing potential divisor: 635
# Currently testing potential divisor: 636
# Currently testing potential divisor: 637
# Currently testing potential divisor: 638
# Currently testing potential divisor: 639
# Currently testing potential divisor: 640
# Currently testing potential divisor: 641
# Currently testing potential divisor: 642
# Currently testing potential divisor: 643
# Currently testing potential divisor: 644
# Currently testing potential divisor: 645
# Currently testing potential divisor: 646
# Currently testing potential divisor: 647
# Currently testing potential divisor: 648
# Currently testing potential divisor: 649
# Currently testing potential divisor: 650
# Currently testing potential divisor: 651
# Currently testing potential divisor: 652
# Currently testing potential divisor: 653
# Currently testing potential divisor: 654
# Currently testing potential divisor: 655
# Currently testing potential divisor: 656
# Currently testing potential divisor: 657
# Currently testing potential divisor: 658
# Currently testing potential divisor: 659
# Currently testing potential divisor: 660
# Currently testing potential divisor: 661
# Currently testing potential divisor: 662
# Currently testing potential divisor: 663
# Currently testing potential divisor: 664
# Currently testing potential divisor: 665
# Currently testing potential divisor: 666
# Currently testing potential divisor: 667
# Currently testing potential divisor: 668
# Currently testing potential divisor: 669
# Currently testing potential divisor: 670
# Currently testing potential divisor: 671
# Currently testing potential divisor: 672
# Currently testing potential divisor: 673
# Currently testing potential divisor: 674
# Currently testing potential divisor: 675
# Currently testing potential divisor: 676
# Currently testing potential divisor: 677
# Currently testing potential divisor: 678
# Currently testing potential divisor: 679
# Currently testing potential divisor: 680
# Currently testing potential divisor: 681
# Currently testing potential divisor: 682
# Currently testing potential divisor: 683
# Currently testing potential divisor: 684
# Currently testing potential divisor: 685
# Currently testing potential divisor: 686
# Currently testing potential divisor: 687
# Currently testing potential divisor: 688
# Currently testing potential divisor: 689
# Currently testing potential divisor: 690
# Currently testing potential divisor: 691
# Currently testing potential divisor: 692
# Currently testing potential divisor: 693
# Currently testing potential divisor: 694
# Currently testing potential divisor: 695
# Currently testing potential divisor: 696
# Currently testing potential divisor: 697
# Currently testing potential divisor: 698
# Currently testing potential divisor: 699
# Currently testing potential divisor: 700
# Currently testing potential divisor: 701
# Currently testing potential divisor: 702
# Currently testing potential divisor: 703
# Currently testing potential divisor: 704
# Currently testing potential divisor: 705
# Currently testing potential divisor: 706
# Currently testing potential divisor: 707
# Currently testing potential divisor: 708
# Currently testing potential divisor: 709
# Currently testing potential divisor: 710
# Currently testing potential divisor: 711
# Currently testing potential divisor: 712
# Currently testing potential divisor: 713
# Currently testing potential divisor: 714
# Currently testing potential divisor: 715
# Currently testing potential divisor: 716
# Currently testing potential divisor: 717
# Currently testing potential divisor: 718
# Currently testing potential divisor: 719
# Currently testing potential divisor: 720
# Currently testing potential divisor: 721
# Currently testing potential divisor: 722
# Currently testing potential divisor: 723
# Currently testing potential divisor: 724
# Currently testing potential divisor: 725
# Currently testing potential divisor: 726
# Currently testing potential divisor: 727
# Currently testing potential divisor: 728
# Currently testing potential divisor: 729
# Currently testing potential divisor: 730
# Currently testing potential divisor: 731
# Currently testing potential divisor: 732
# Currently testing potential divisor: 733
# Currently testing potential divisor: 734
# Currently testing potential divisor: 735
# Currently testing potential divisor: 736
# Currently testing potential divisor: 737
# Currently testing potential divisor: 738
# Currently testing potential divisor: 739
# Currently testing potential divisor: 740
# Currently testing potential divisor: 741
# Currently testing potential divisor: 742
# Currently testing potential divisor: 743
# Currently testing potential divisor: 744
# Currently testing potential divisor: 745
# Currently testing potential divisor: 746
# Currently testing potential divisor: 747
# Currently testing potential divisor: 748
# Currently testing potential divisor: 749
# Currently testing potential divisor: 750
# Currently testing potential divisor: 751
# Currently testing potential divisor: 752
# Currently testing potential divisor: 753
# Currently testing potential divisor: 754
# Currently testing potential divisor: 755
# Currently testing potential divisor: 756
# Currently testing potential divisor: 757
# Currently testing potential divisor: 758
# Currently testing potential divisor: 759
# Currently testing potential divisor: 760
# Currently testing potential divisor: 761
# Currently testing potential divisor: 762
# Currently testing potential divisor: 763
# Currently testing potential divisor: 764
# Currently testing potential divisor: 765
# Currently testing potential divisor: 766
# Currently testing potential divisor: 767
# Currently testing potential divisor: 768
# Currently testing potential divisor: 769
# Currently testing potential divisor: 770
# Currently testing potential divisor: 771
# Currently testing potential divisor: 772
# Currently testing potential divisor: 773
# Currently testing potential divisor: 774
# Currently testing potential divisor: 775
# Currently testing potential divisor: 776
# Currently testing potential divisor: 777
# Currently testing potential divisor: 778
# Currently testing potential divisor: 779
# Currently testing potential divisor: 780
# Currently testing potential divisor: 781
# Currently testing potential divisor: 782
# Currently testing potential divisor: 783
# Currently testing potential divisor: 784
# Currently testing potential divisor: 785
# Currently testing potential divisor: 786
# Currently testing potential divisor: 787
# Currently testing potential divisor: 788
# Currently testing potential divisor: 789
# Currently testing potential divisor: 790
# Currently testing potential divisor: 791
# Currently testing potential divisor: 792
# Currently testing potential divisor: 793
# Currently testing potential divisor: 794
# Currently testing potential divisor: 795
# Currently testing potential divisor: 796
# Currently testing potential divisor: 797
# Currently testing potential divisor: 798
# Currently testing potential divisor: 799
# Currently testing potential divisor: 800
# Currently testing potential divisor: 801
# Currently testing potential divisor: 802
# Currently testing potential divisor: 803
# Currently testing potential divisor: 804
# Currently testing potential divisor: 805
# Currently testing potential divisor: 806
# Currently testing potential divisor: 807
# Currently testing potential divisor: 808
# Currently testing potential divisor: 809
# Currently testing potential divisor: 810
# Currently testing potential divisor: 811
# Currently testing potential divisor: 812
# Currently testing potential divisor: 813
# Currently testing potential divisor: 814
# Currently testing potential divisor: 815
# Currently testing potential divisor: 816
# Currently testing potential divisor: 817
# Currently testing potential divisor: 818
# Currently testing potential divisor: 819
# Currently testing potential divisor: 820
# Currently testing potential divisor: 821
# Currently testing potential divisor: 822
# Currently testing potential divisor: 823
# Currently testing potential divisor: 824
# Currently testing potential divisor: 825
# Currently testing potential divisor: 826
# Currently testing potential divisor: 827
# Currently testing potential divisor: 828
# Currently testing potential divisor: 829
# Currently testing potential divisor: 830
# Currently testing potential divisor: 831
# Currently testing potential divisor: 832
# Currently testing potential divisor: 833
# Currently testing potential divisor: 834
# Currently testing potential divisor: 835
# Currently testing potential divisor: 836
# Currently testing potential divisor: 837
# Currently testing potential divisor: 838
# Currently testing potential divisor: 839
# Currently testing potential divisor: 840
# Currently testing potential divisor: 841
# Currently testing potential divisor: 842
# Currently testing potential divisor: 843
# Currently testing potential divisor: 844
# Currently testing potential divisor: 845
# Currently testing potential divisor: 846
# Currently testing potential divisor: 847
# Currently testing potential divisor: 848
# Currently testing potential divisor: 849
# Currently testing potential divisor: 850
# Currently testing potential divisor: 851
# Currently testing potential divisor: 852
# Currently testing potential divisor: 853
# Currently testing potential divisor: 854
# Currently testing potential divisor: 855
# Currently testing potential divisor: 856
# Currently testing potential divisor: 857
# Currently testing potential divisor: 858
# Currently testing potential divisor: 859
# Currently testing potential divisor: 860
# Currently testing potential divisor: 861
# Currently testing potential divisor: 862
# Currently testing potential divisor: 863
# Currently testing potential divisor: 864
# Currently testing potential divisor: 865
# Currently testing potential divisor: 866
# Currently testing potential divisor: 867
# Currently testing potential divisor: 868
# Currently testing potential divisor: 869
# Currently testing potential divisor: 870
# Currently testing potential divisor: 871
# Currently testing potential divisor: 872
# Currently testing potential divisor: 873
# Currently testing potential divisor: 874
# Currently testing potential divisor: 875
# Currently testing potential divisor: 876
# Currently testing potential divisor: 877
# Currently testing potential divisor: 878
# Currently testing potential divisor: 879
# Currently testing potential divisor: 880
# Currently testing potential divisor: 881
# Currently testing potential divisor: 882
# Currently testing potential divisor: 883
# Currently testing potential divisor: 884
# Currently testing potential divisor: 885
# Currently testing potential divisor: 886
# Currently testing potential divisor: 887
# Currently testing potential divisor: 888
# Currently testing potential divisor: 889
# Currently testing potential divisor: 890
# Currently testing potential divisor: 891
# Currently testing potential divisor: 892
# Currently testing potential divisor: 893
# Currently testing potential divisor: 894
# Currently testing potential divisor: 895
# Currently testing potential divisor: 896
# Currently testing potential divisor: 897
# Currently testing potential divisor: 898
# Currently testing potential divisor: 899
# Currently testing potential divisor: 900
# Currently testing potential divisor: 901
# Currently testing potential divisor: 902
# Currently testing potential divisor: 903
# Currently testing potential divisor: 904
# Currently testing potential divisor: 905
# Currently testing potential divisor: 906
# Currently testing potential divisor: 907
# Currently testing potential divisor: 908
# Currently testing potential divisor: 909
# Currently testing potential divisor: 910
# Currently testing potential divisor: 911
# Currently testing potential divisor: 912
# Currently testing potential divisor: 913
# Currently testing potential divisor: 914
# Currently testing potential divisor: 915
# Currently testing potential divisor: 916
# Currently testing potential divisor: 917
# Currently testing potential divisor: 918
# Currently testing potential divisor: 919
# Currently testing potential divisor: 920
# Currently testing potential divisor: 921
# Currently testing potential divisor: 922
# Currently testing potential divisor: 923
# Currently testing potential divisor: 924
# Currently testing potential divisor: 925
# Currently testing potential divisor: 926
# Currently testing potential divisor: 927
# Currently testing potential divisor: 928
# Currently testing potential divisor: 929
# Currently testing potential divisor: 930
# Currently testing potential divisor: 931
# Currently testing potential divisor: 932
# Currently testing potential divisor: 933
# Currently testing potential divisor: 934
# Currently testing potential divisor: 935
# Currently testing potential divisor: 936
# Currently testing potential divisor: 937
# Currently testing potential divisor: 938
# Currently testing potential divisor: 939
# Currently testing potential divisor: 940
# Currently testing potential divisor: 941
# Currently testing potential divisor: 942
# Currently testing potential divisor: 943
# Currently testing potential divisor: 944
# Currently testing potential divisor: 945
# Currently testing potential divisor: 946
# Currently testing potential divisor: 947
# Currently testing potential divisor: 948
# Currently testing potential divisor: 949
# Currently testing potential divisor: 950
# Currently testing potential divisor: 951
# Currently testing potential divisor: 952
# Currently testing potential divisor: 953
# Currently testing potential divisor: 954
# Currently testing potential divisor: 955
# Currently testing potential divisor: 956
# Currently testing potential divisor: 957
# Currently testing potential divisor: 958
# Currently testing potential divisor: 959
# Currently testing potential divisor: 960
# Currently testing potential divisor: 961
# Currently testing potential divisor: 962
# Currently testing potential divisor: 963
# Currently testing potential divisor: 964
# Currently testing potential divisor: 965
# Currently testing potential divisor: 966
# Currently testing potential divisor: 967
# Currently testing potential divisor: 968
# Currently testing potential divisor: 969
# Currently testing potential divisor: 970
# Currently testing potential divisor: 971
# Currently testing potential divisor: 972
# Currently testing potential divisor: 973
# Currently testing potential divisor: 974
# Currently testing potential divisor: 975
# Currently testing potential divisor: 976
# Currently testing potential divisor: 977
# Currently testing potential divisor: 978
# Currently testing potential divisor: 979
# Currently testing potential divisor: 980
# Currently testing potential divisor: 981
# Currently testing potential divisor: 982
# Currently testing potential divisor: 983
# Currently testing potential divisor: 984
# Currently testing potential divisor: 985
# Currently testing potential divisor: 986
# Currently testing potential divisor: 987
# Currently testing potential divisor: 988
# Currently testing potential divisor: 989
# Currently testing potential divisor: 990
# Currently testing potential divisor: 991
# Currently testing potential divisor: 992
# Currently testing potential divisor: 993
# Currently testing potential divisor: 994
# Currently testing potential divisor: 995
# Currently testing potential divisor: 996
# Currently testing potential divisor: 997
# Currently testing potential divisor: 998
# Currently testing potential divisor: 999
# Currently testing potential divisor: 1000
# Aha! Found a divisor 2000 is divisble by 1000
# Currently testing potential divisor: 1001
# Currently testing potential divisor: 1002
# Currently testing potential divisor: 1003
# Currently testing potential divisor: 1004
# Currently testing potential divisor: 1005
# Currently testing potential divisor: 1006
# Currently testing potential divisor: 1007
# Currently testing potential divisor: 1008
# Currently testing potential divisor: 1009
# Currently testing potential divisor: 1010
# Currently testing potential divisor: 1011
# Currently testing potential divisor: 1012
# Currently testing potential divisor: 1013
# Currently testing potential divisor: 1014
# Currently testing potential divisor: 1015
# Currently testing potential divisor: 1016
# Currently testing potential divisor: 1017
# Currently testing potential divisor: 1018
# Currently testing potential divisor: 1019
# Currently testing potential divisor: 1020
# Currently testing potential divisor: 1021
# Currently testing potential divisor: 1022
# Currently testing potential divisor: 1023
# Currently testing potential divisor: 1024
# Currently testing potential divisor: 1025
# Currently testing potential divisor: 1026
# Currently testing potential divisor: 1027
# Currently testing potential divisor: 1028
# Currently testing potential divisor: 1029
# Currently testing potential divisor: 1030
# Currently testing potential divisor: 1031
# Currently testing potential divisor: 1032
# Currently testing potential divisor: 1033
# Currently testing potential divisor: 1034
# Currently testing potential divisor: 1035
# Currently testing potential divisor: 1036
# Currently testing potential divisor: 1037
# Currently testing potential divisor: 1038
# Currently testing potential divisor: 1039
# Currently testing potential divisor: 1040
# Currently testing potential divisor: 1041
# Currently testing potential divisor: 1042
# Currently testing potential divisor: 1043
# Currently testing potential divisor: 1044
# Currently testing potential divisor: 1045
# Currently testing potential divisor: 1046
# Currently testing potential divisor: 1047
# Currently testing potential divisor: 1048
# Currently testing potential divisor: 1049
# Currently testing potential divisor: 1050
# Currently testing potential divisor: 1051
# Currently testing potential divisor: 1052
# Currently testing potential divisor: 1053
# Currently testing potential divisor: 1054
# Currently testing potential divisor: 1055
# Currently testing potential divisor: 1056
# Currently testing potential divisor: 1057
# Currently testing potential divisor: 1058
# Currently testing potential divisor: 1059
# Currently testing potential divisor: 1060
# Currently testing potential divisor: 1061
# Currently testing potential divisor: 1062
# Currently testing potential divisor: 1063
# Currently testing potential divisor: 1064
# Currently testing potential divisor: 1065
# Currently testing potential divisor: 1066
# Currently testing potential divisor: 1067
# Currently testing potential divisor: 1068
# Currently testing potential divisor: 1069
# Currently testing potential divisor: 1070
# Currently testing potential divisor: 1071
# Currently testing potential divisor: 1072
# Currently testing potential divisor: 1073
# Currently testing potential divisor: 1074
# Currently testing potential divisor: 1075
# Currently testing potential divisor: 1076
# Currently testing potential divisor: 1077
# Currently testing potential divisor: 1078
# Currently testing potential divisor: 1079
# Currently testing potential divisor: 1080
# Currently testing potential divisor: 1081
# Currently testing potential divisor: 1082
# Currently testing potential divisor: 1083
# Currently testing potential divisor: 1084
# Currently testing potential divisor: 1085
# Currently testing potential divisor: 1086
# Currently testing potential divisor: 1087
# Currently testing potential divisor: 1088
# Currently testing potential divisor: 1089
# Currently testing potential divisor: 1090
# Currently testing potential divisor: 1091
# Currently testing potential divisor: 1092
# Currently testing potential divisor: 1093
# Currently testing potential divisor: 1094
# Currently testing potential divisor: 1095
# Currently testing potential divisor: 1096
# Currently testing potential divisor: 1097
# Currently testing potential divisor: 1098
# Currently testing potential divisor: 1099
# Currently testing potential divisor: 1100
# Currently testing potential divisor: 1101
# Currently testing potential divisor: 1102
# Currently testing potential divisor: 1103
# Currently testing potential divisor: 1104
# Currently testing potential divisor: 1105
# Currently testing potential divisor: 1106
# Currently testing potential divisor: 1107
# Currently testing potential divisor: 1108
# Currently testing potential divisor: 1109
# Currently testing potential divisor: 1110
# Currently testing potential divisor: 1111
# Currently testing potential divisor: 1112
# Currently testing potential divisor: 1113
# Currently testing potential divisor: 1114
# Currently testing potential divisor: 1115
# Currently testing potential divisor: 1116
# Currently testing potential divisor: 1117
# Currently testing potential divisor: 1118
# Currently testing potential divisor: 1119
# Currently testing potential divisor: 1120
# Currently testing potential divisor: 1121
# Currently testing potential divisor: 1122
# Currently testing potential divisor: 1123
# Currently testing potential divisor: 1124
# Currently testing potential divisor: 1125
# Currently testing potential divisor: 1126
# Currently testing potential divisor: 1127
# Currently testing potential divisor: 1128
# Currently testing potential divisor: 1129
# Currently testing potential divisor: 1130
# Currently testing potential divisor: 1131
# Currently testing potential divisor: 1132
# Currently testing potential divisor: 1133
# Currently testing potential divisor: 1134
# Currently testing potential divisor: 1135
# Currently testing potential divisor: 1136
# Currently testing potential divisor: 1137
# Currently testing potential divisor: 1138
# Currently testing potential divisor: 1139
# Currently testing potential divisor: 1140
# Currently testing potential divisor: 1141
# Currently testing potential divisor: 1142
# Currently testing potential divisor: 1143
# Currently testing potential divisor: 1144
# Currently testing potential divisor: 1145
# Currently testing potential divisor: 1146
# Currently testing potential divisor: 1147
# Currently testing potential divisor: 1148
# Currently testing potential divisor: 1149
# Currently testing potential divisor: 1150
# Currently testing potential divisor: 1151
# ...
# Currently testing potential divisor: 1619
# Currently testing potential divisor: 1620
# Currently testing potential divisor: 1621
# Currently testing potential divisor: 1622
# Currently testing potential divisor: 1623
# Currently testing potential divisor: 1624
# Currently testing potential divisor: 1625
# Currently testing potential divisor: 1626
# Currently testing potential divisor: 1627
# Currently testing potential divisor: 1628
# Currently testing potential divisor: 1629
# Currently testing potential divisor: 1630
# Currently testing potential divisor: 1631
# Currently testing potential divisor: 1632
# Currently testing potential divisor: 1633
# Currently testing potential divisor: 1634
# Currently testing potential divisor: 1635
# Currently testing potential divisor: 1636
# Currently testing potential divisor: 1637
# Currently testing potential divisor: 1638
# Currently testing potential divisor: 1639
# Currently testing potential divisor: 1640
# Currently testing potential divisor: 1641
# Currently testing potential divisor: 1642
# Currently testing potential divisor: 1643
# Currently testing potential divisor: 1644
# Currently testing potential divisor: 1645
# Currently testing potential divisor: 1646
# Currently testing potential divisor: 1647
# Currently testing potential divisor: 1648
# Currently testing potential divisor: 1649
# Currently testing potential divisor: 1650
# Currently testing potential divisor: 1651
# Currently testing potential divisor: 1652
# Currently testing potential divisor: 1653
# Currently testing potential divisor: 1654
# Currently testing potential divisor: 1655
# Currently testing potential divisor: 1656
# Currently testing potential divisor: 1657
# Currently testing potential divisor: 1658
# Currently testing potential divisor: 1659
# Currently testing potential divisor: 1660
# Currently testing potential divisor: 1661
# Currently testing potential divisor: 1662
# Currently testing potential divisor: 1663
# Currently testing potential divisor: 1664
# Currently testing potential divisor: 1665
# Currently testing potential divisor: 1666
# Currently testing potential divisor: 1667
# Currently testing potential divisor: 1668
# Currently testing potential divisor: 1669
# Currently testing potential divisor: 1670
# Currently testing potential divisor: 1671
# Currently testing potential divisor: 1672
# Currently testing potential divisor: 1673
# Currently testing potential divisor: 1674
# Currently testing potential divisor: 1675
# Currently testing potential divisor: 1676
# Currently testing potential divisor: 1677
# Currently testing potential divisor: 1678
# Currently testing potential divisor: 1679
# Currently testing potential divisor: 1680
# Currently testing potential divisor: 1681
# Currently testing potential divisor: 1682
# Currently testing potential divisor: 1683
# Currently testing potential divisor: 1684
# Currently testing potential divisor: 1685
# Currently testing potential divisor: 1686
# Currently testing potential divisor: 1687
# Currently testing potential divisor: 1688
# Currently testing potential divisor: 1689
# Currently testing potential divisor: 1690
# Currently testing potential divisor: 1691
# Currently testing potential divisor: 1692
# Currently testing potential divisor: 1693
# Currently testing potential divisor: 1694
# Currently testing potential divisor: 1695
# Currently testing potential divisor: 1696
# Currently testing potential divisor: 1697
# Currently testing potential divisor: 1698
# Currently testing potential divisor: 1699
# Currently testing potential divisor: 1700
# Currently testing potential divisor: 1701
# Currently testing potential divisor: 1702
# Currently testing potential divisor: 1703
# Currently testing potential divisor: 1704
# Currently testing potential divisor: 1705
# Currently testing potential divisor: 1706
# Currently testing potential divisor: 1707
# Currently testing potential divisor: 1708
# Currently testing potential divisor: 1709
# Currently testing potential divisor: 1710
# Currently testing potential divisor: 1711
# Currently testing potential divisor: 1712
# Currently testing potential divisor: 1713
# Currently testing potential divisor: 1714
# Currently testing potential divisor: 1715
# Currently testing potential divisor: 1716
# Currently testing potential divisor: 1717
# Currently testing potential divisor: 1718
# Currently testing potential divisor: 1719
# Currently testing potential divisor: 1720
# Currently testing potential divisor: 1721
# Currently testing potential divisor: 1722
# Currently testing potential divisor: 1723
# Currently testing potential divisor: 1724
# Currently testing potential divisor: 1725
# Currently testing potential divisor: 1726
# Currently testing potential divisor: 1727
# Currently testing potential divisor: 1728
# Currently testing potential divisor: 1729
# Currently testing potential divisor: 1730
# Currently testing potential divisor: 1731
# Currently testing potential divisor: 1732
# Currently testing potential divisor: 1733
# Currently testing potential divisor: 1734
# Currently testing potential divisor: 1735
# Currently testing potential divisor: 1736
# Currently testing potential divisor: 1737
# Currently testing potential divisor: 1738
# Currently testing potential divisor: 1739
# Currently testing potential divisor: 1740
# Currently testing potential divisor: 1741
# Currently testing potential divisor: 1742
# Currently testing potential divisor: 1743
# Currently testing potential divisor: 1744
# Currently testing potential divisor: 1745
# Currently testing potential divisor: 1746
# Currently testing potential divisor: 1747
# Currently testing potential divisor: 1748
# Currently testing potential divisor: 1749
# Currently testing potential divisor: 1750
# Currently testing potential divisor: 1751
# Currently testing potential divisor: 1752
# Currently testing potential divisor: 1753
# Currently testing potential divisor: 1754
# Currently testing potential divisor: 1755
# Currently testing potential divisor: 1756
# Currently testing potential divisor: 1757
# Currently testing potential divisor: 1758
# Currently testing potential divisor: 1759
# Currently testing potential divisor: 1760
# Currently testing potential divisor: 1761
# Currently testing potential divisor: 1762
# Currently testing potential divisor: 1763
# Currently testing potential divisor: 1764
# Currently testing potential divisor: 1765
# Currently testing potential divisor: 1766
# Currently testing potential divisor: 1767
# Currently testing potential divisor: 1768
# Currently testing potential divisor: 1769
# Currently testing potential divisor: 1770
# Currently testing potential divisor: 1771
# Currently testing potential divisor: 1772
# Currently testing potential divisor: 1773
# Currently testing potential divisor: 1774
# Currently testing potential divisor: 1775
# Currently testing potential divisor: 1776
# Currently testing potential divisor: 1777
# Currently testing potential divisor: 1778
# Currently testing potential divisor: 1779
# Currently testing potential divisor: 1780
# Currently testing potential divisor: 1781
# Currently testing potential divisor: 1782
# Currently testing potential divisor: 1783
# Currently testing potential divisor: 1784
# Currently testing potential divisor: 1785
# Currently testing potential divisor: 1786
# Currently testing potential divisor: 1787
# Currently testing potential divisor: 1788
# Currently testing potential divisor: 1789
# Currently testing potential divisor: 1790
# Currently testing potential divisor: 1791
# Currently testing potential divisor: 1792
# Currently testing potential divisor: 1793
# Currently testing potential divisor: 1794
# Currently testing potential divisor: 1795
# Currently testing potential divisor: 1796
# Currently testing potential divisor: 1797
# Currently testing potential divisor: 1798
# Currently testing potential divisor: 1799
# Currently testing potential divisor: 1800
# Currently testing potential divisor: 1801
# Currently testing potential divisor: 1802
# Currently testing potential divisor: 1803
# Currently testing potential divisor: 1804
# Currently testing potential divisor: 1805
# Currently testing potential divisor: 1806
# Currently testing potential divisor: 1807
# Currently testing potential divisor: 1808
# Currently testing potential divisor: 1809
# Currently testing potential divisor: 1810
# Currently testing potential divisor: 1811
# Currently testing potential divisor: 1812
# Currently testing potential divisor: 1813
# Currently testing potential divisor: 1814
# Currently testing potential divisor: 1815
# Currently testing potential divisor: 1816
# Currently testing potential divisor: 1817
# Currently testing potential divisor: 1818
# Currently testing potential divisor: 1819
# Currently testing potential divisor: 1820
# Currently testing potential divisor: 1821
# Currently testing potential divisor: 1822
# Currently testing potential divisor: 1823
# Currently testing potential divisor: 1824
# Currently testing potential divisor: 1825
# Currently testing potential divisor: 1826
# Currently testing potential divisor: 1827
# Currently testing potential divisor: 1828
# Currently testing potential divisor: 1829
# Currently testing potential divisor: 1830
# Currently testing potential divisor: 1831
# Currently testing potential divisor: 1832
# Currently testing potential divisor: 1833
# Currently testing potential divisor: 1834
# Currently testing potential divisor: 1835
# Currently testing potential divisor: 1836
# Currently testing potential divisor: 1837
# Currently testing potential divisor: 1838
# Currently testing potential divisor: 1839
# Currently testing potential divisor: 1840
# Currently testing potential divisor: 1841
# Currently testing potential divisor: 1842
# Currently testing potential divisor: 1843
# Currently testing potential divisor: 1844
# Currently testing potential divisor: 1845
# Currently testing potential divisor: 1846
# Currently testing potential divisor: 1847
# Currently testing potential divisor: 1848
# Currently testing potential divisor: 1849
# Currently testing potential divisor: 1850
# Currently testing potential divisor: 1851
# Currently testing potential divisor: 1852
# Currently testing potential divisor: 1853
# Currently testing potential divisor: 1854
# Currently testing potential divisor: 1855
# Currently testing potential divisor: 1856
# Currently testing potential divisor: 1857
# Currently testing potential divisor: 1858
# Currently testing potential divisor: 1859
# Currently testing potential divisor: 1860
# Currently testing potential divisor: 1861
# Currently testing potential divisor: 1862
# Currently testing potential divisor: 1863
# Currently testing potential divisor: 1864
# Currently testing potential divisor: 1865
# Currently testing potential divisor: 1866
# Currently testing potential divisor: 1867
# Currently testing potential divisor: 1868
# Currently testing potential divisor: 1869
# Currently testing potential divisor: 1870
# Currently testing potential divisor: 1871
# Currently testing potential divisor: 1872
# Currently testing potential divisor: 1873
# Currently testing potential divisor: 1874
# Currently testing potential divisor: 1875
# Currently testing potential divisor: 1876
# Currently testing potential divisor: 1877
# Currently testing potential divisor: 1878
# Currently testing potential divisor: 1879
# Currently testing potential divisor: 1880
# Currently testing potential divisor: 1881
# Currently testing potential divisor: 1882
# Currently testing potential divisor: 1883
# Currently testing potential divisor: 1884
# Currently testing potential divisor: 1885
# Currently testing potential divisor: 1886
# Currently testing potential divisor: 1887
# Currently testing potential divisor: 1888
# Currently testing potential divisor: 1889
# Currently testing potential divisor: 1890
# Currently testing potential divisor: 1891
# Currently testing potential divisor: 1892
# Currently testing potential divisor: 1893
# Currently testing potential divisor: 1894
# Currently testing potential divisor: 1895
# Currently testing potential divisor: 1896
# Currently testing potential divisor: 1897
# Currently testing potential divisor: 1898
# Currently testing potential divisor: 1899
# Currently testing potential divisor: 1900
# Currently testing potential divisor: 1901
# Currently testing potential divisor: 1902
# Currently testing potential divisor: 1903
# Currently testing potential divisor: 1904
# Currently testing potential divisor: 1905
# Currently testing potential divisor: 1906
# Currently testing potential divisor: 1907
# Currently testing potential divisor: 1908
# Currently testing potential divisor: 1909
# Currently testing potential divisor: 1910
# Currently testing potential divisor: 1911
# Currently testing potential divisor: 1912
# Currently testing potential divisor: 1913
# Currently testing potential divisor: 1914
# Currently testing potential divisor: 1915
# Currently testing potential divisor: 1916
# Currently testing potential divisor: 1917
# Currently testing potential divisor: 1918
# Currently testing potential divisor: 1919
# Currently testing potential divisor: 1920
# Currently testing potential divisor: 1921
# Currently testing potential divisor: 1922
# Currently testing potential divisor: 1923
# Currently testing potential divisor: 1924
# Currently testing potential divisor: 1925
# Currently testing potential divisor: 1926
# Currently testing potential divisor: 1927
# Currently testing potential divisor: 1928
# Currently testing potential divisor: 1929
# Currently testing potential divisor: 1930
# Currently testing potential divisor: 1931
# Currently testing potential divisor: 1932
# Currently testing potential divisor: 1933
# Currently testing potential divisor: 1934
# Currently testing potential divisor: 1935
# Currently testing potential divisor: 1936
# Currently testing potential divisor: 1937
# Currently testing potential divisor: 1938
# Currently testing potential divisor: 1939
# Currently testing potential divisor: 1940
# Currently testing potential divisor: 1941
# Currently testing potential divisor: 1942
# Currently testing potential divisor: 1943
# Currently testing potential divisor: 1944
# Currently testing potential divisor: 1945
# Currently testing potential divisor: 1946
# Currently testing potential divisor: 1947
# Currently testing potential divisor: 1948
# Currently testing potential divisor: 1949
# Currently testing potential divisor: 1950
# Currently testing potential divisor: 1951
# Currently testing potential divisor: 1952
# Currently testing potential divisor: 1953
# Currently testing potential divisor: 1954
# Currently testing potential divisor: 1955
# Currently testing potential divisor: 1956
# Currently testing potential divisor: 1957
# Currently testing potential divisor: 1958
# Currently testing potential divisor: 1959
# Currently testing potential divisor: 1960
# Currently testing potential divisor: 1961
# Currently testing potential divisor: 1962
# Currently testing potential divisor: 1963
# Currently testing potential divisor: 1964
# Currently testing potential divisor: 1965
# Currently testing potential divisor: 1966
# Currently testing potential divisor: 1967
# Currently testing potential divisor: 1968
# Currently testing potential divisor: 1969
# Currently testing potential divisor: 1970
# Currently testing potential divisor: 1971
# Currently testing potential divisor: 1972
# Currently testing potential divisor: 1973
# Currently testing potential divisor: 1974
# Currently testing potential divisor: 1975
# Currently testing potential divisor: 1976
# Currently testing potential divisor: 1977
# Currently testing potential divisor: 1978
# Currently testing potential divisor: 1979
# Currently testing potential divisor: 1980
# Currently testing potential divisor: 1981
# Currently testing potential divisor: 1982
# Currently testing potential divisor: 1983
# Currently testing potential divisor: 1984
# Currently testing potential divisor: 1985
# Currently testing potential divisor: 1986
# Currently testing potential divisor: 1987
# Currently testing potential divisor: 1988
# Currently testing potential divisor: 1989
# Currently testing potential divisor: 1990
# Currently testing potential divisor: 1991
# Currently testing potential divisor: 1992
# Currently testing potential divisor: 1993
# Currently testing potential divisor: 1994
# Currently testing potential divisor: 1995
# Currently testing potential divisor: 1996
# Currently testing potential divisor: 1997
# Currently testing potential divisor: 1998

# %% [markdown]
# Now if no divisor was found then inform the user

# %%
if is_number_prime==False:
    print("I couldn't fin any divisors so the number must be prime, congrats")

# %%
stop = timeit.default_timer()
duration=stop-start
print("It took me "+str(duration)+"seconds to run")
# Out:
# It took me 0.550266008998733seconds to run

# %%
def is_prime(test_number):
    
    potential_divisors=np.arange(2,test_number-1)
    is_number_prime=True

    for divisor in potential_divisors:
        remainder=test_number%divisor

        #if remainder is zero the the number is a divisor so make the is_number_prime be true
        if remainder == 0:
            is_number_prime=False
            
    return is_number_prime

# %%
max_prime=10000
test_numbers=np.arange(3,max_prime)
results=np.zeros(len(test_numbers))

# %%
for k in range(len(test_numbers)):
    was_number_prime=is_prime(test_numbers[k])
    if was_number_prime==True:
        results[k]=1

# %%
# plt.figure()
# plt.stem(test_numbers,results)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bins=np.arange(0,max_prime,100)
count,edges,numbers=stats.binned_statistic(test_numbers,results,bins=bins,statistic='sum')
print(bins)
print(count)

# %%
plt.figure()
plt.bar(edges[0:-1],count,width=100)
plt.xlabel('Bin center')
plt.ylabel('# of primes in bin')

# %%
edges
