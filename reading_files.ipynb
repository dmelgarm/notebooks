# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
#read the file using genfromtxt

file_path='/Users/dmelgar/Classes/GEOL410/data/GEO914_wi.txt'

#If you use windows it will likely look like this:

# file_path='C://Users//demlgar//some_folder//GEO914.txt'

# %%
disp = np.genfromtxt(file_path)

# %%
time = disp[:,0]
north = disp[:,1]
east = disp[:,2]
up = disp[:,3]

# %%
#now make a plot

plt.figure()

plt.subplot(311)
plt.plot(time,north)
plt.ylabel('North (m)')
plt.grid()

plt.subplot(312)
plt.plot(time,north)
plt.ylabel('East (m)')
plt.grid()


plt.subplot(313)
plt.plot(time,north)
plt.ylabel('Up (m)')
plt.xlabel('Time (seconds)')
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
